# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# Use the kagglehub client library to attach Kaggle resources like competitions, datasets, and models to your session
# Learn more about kagglehub: https://github.com/Kaggle/kagglehub/blob/main/README.md

import kagglehub
# kagglehub.dataset_download('<owner>/<dataset-slug>')

# %%
import os

for dirname, _, filenames in os.walk('/kaggle/input'):
    print(dirname)
# Out:
# /kaggle/input
# /kaggle/input/datasets
# /kaggle/input/datasets/kshitij192
# /kaggle/input/datasets/kshitij192/cars-image-dataset
# /kaggle/input/datasets/kshitij192/cars-image-dataset/Cars Dataset
# /kaggle/input/datasets/kshitij192/cars-image-dataset/Cars Dataset/test
# /kaggle/input/datasets/kshitij192/cars-image-dataset/Cars Dataset/test/Hyundai Creta
# /kaggle/input/datasets/kshitij192/cars-image-dataset/Cars Dataset/test/Tata Safari
# /kaggle/input/datasets/kshitij192/cars-image-dataset/Cars Dataset/test/Swift
# /kaggle/input/datasets/kshitij192/cars-image-dataset/Cars Dataset/test/Mahindra Scorpio
# /kaggle/input/datasets/kshitij192/cars-image-dataset/Cars Dataset/test/Toyota Innova
# /kaggle/input/datasets/kshitij192/cars-image-dataset/Cars Dataset/test/Rolls Royce
# /kaggle/input/datasets/kshitij192/cars-image-dataset/Cars Dataset/test/Audi
# /kaggle/input/datasets/kshitij192/cars-image-dataset/Cars Dataset/train
# /kaggle/input/datasets/kshitij192/cars-image-dataset/Cars Dataset/train/Hyundai Creta
# /kaggle/input/datasets/kshitij192/cars-image-dataset/Cars Dataset/train/Tata Safari
# /kaggle/input/datasets/kshitij192/cars-image-dataset/Cars Dataset/train/Swift
# /kaggle/input/datasets/kshitij192/cars-image-dataset/Cars Dataset/train/Mahindra Scorpio
# /kaggle/input/datasets/kshitij192/cars-image-dataset/Cars Dataset/train/Toyota Innova
# /kaggle/input/datasets/kshitij192/cars-image-dataset/Cars Dataset/train/Rolls Royce
# /kaggle/input/datasets/kshitij192/cars-image-dataset/Cars Dataset/train/Audi

# %%
# ==========================
# IMPORT LIBRARIES
# ==========================

import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf

from tensorflow.keras import layers, Model
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

from sklearn.metrics import (
    confusion_matrix,
    classification_report,
    precision_score,
    recall_score,
    f1_score
)

print("TensorFlow Version:", tf.__version__)

# ==========================
# SHOW DATASET STRUCTURE
# ==========================

DATASET_PATH = "/kaggle/input/datasets/kshitij192/cars-image-dataset/Cars Dataset"

for dirname, _, _ in os.walk(DATASET_PATH):
    print(dirname)

# ==========================
# TRAIN & TEST PATHS
# ==========================

TRAIN_PATH = DATASET_PATH + "/train"
TEST_PATH  = DATASET_PATH + "/test"

print("Train Exists:", os.path.exists(TRAIN_PATH))
print("Test Exists:", os.path.exists(TEST_PATH))

# ==========================
# PARAMETERS
# ==========================

IMG_SIZE = 128
BATCH_SIZE = 32
EPOCHS = 20

# ==========================
# LOAD DATASET
# ==========================

train_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    TRAIN_PATH,
    validation_split=0.2,
    subset="training",
    seed=123,
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE
)

val_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    TRAIN_PATH,
    validation_split=0.2,
    subset="validation",
    seed=123,
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE
)

test_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    TEST_PATH,
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE
)

# ==========================
# CLASS NAMES
# ==========================

class_names = train_dataset.class_names
NUM_CLASSES = len(class_names)

print("Classes:", class_names)

# ==========================
# PREFETCH OPTIMIZATION
# ==========================

AUTOTUNE = tf.data.AUTOTUNE

train_dataset = train_dataset.prefetch(AUTOTUNE)
val_dataset = val_dataset.prefetch(AUTOTUNE)
test_dataset = test_dataset.prefetch(AUTOTUNE)

# ==========================
# VISUALIZE DATA
# ==========================

plt.figure(figsize=(10,10))

for images, labels in train_dataset.take(1):
    for i in range(9):
        plt.subplot(3,3,i+1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")

plt.show()

# ==========================
# DATA AUGMENTATION
# ==========================

augment = tf.keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.2),
    layers.RandomZoom(0.2),
    layers.RandomContrast(0.2)
])

# ==========================
# ATTENTION BLOCK
# ==========================

def attention(x):
    ch = x.shape[-1]

    w = layers.GlobalAveragePooling2D()(x)
    w = layers.Dense(ch//8, activation="relu")(w)
    w = layers.Dense(ch, activation="sigmoid")(w)
    w = layers.Reshape((1,1,ch))(w)

    return layers.Multiply()([x,w])

# ==========================
# RESIDUAL BLOCK
# ==========================

def residual(x, filters):

    shortcut = layers.Conv2D(filters, 1, padding="same")(x)

    x = layers.Conv2D(filters, 3, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)

    x = layers.Conv2D(filters, 3, padding="same")(x)
    x = layers.BatchNormalization()(x)

    x = layers.Add()([x, shortcut])
    x = layers.ReLU()(x)

    return x

# ==========================
# MULTISCALE BLOCK
# ==========================

def multiscale(x, f):

    a = layers.Conv2D(f, 1, activation="relu", padding="same")(x)
    b = layers.Conv2D(f, 3, activation="relu", padding="same")(x)
    c = layers.Conv2D(f, 5, activation="relu", padding="same")(x)

    return layers.Concatenate()([a,b,c])

# ==========================
# MODEL ARCHITECTURE
# ==========================

def build_model():

    inp = layers.Input(shape=(IMG_SIZE, IMG_SIZE, 3))

    x = augment(inp)
    x = layers.Rescaling(1./255)(x)

    x = layers.Conv2D(32, 3, activation="relu", padding="same")(x)
    x = layers.MaxPooling2D()(x)

    x = multiscale(x, 32)

    x = residual(x, 64)
    x = layers.MaxPooling2D()(x)

    x = attention(x)

    x = residual(x, 128)
    x = layers.MaxPooling2D()(x)

    x = layers.GlobalAveragePooling2D()(x)

    x = layers.Dropout(0.4)(x)
    x = layers.Dense(256, activation="relu")(x)

    out = layers.Dense(NUM_CLASSES, activation="softmax")(x)

    return Model(inp, out)

model = build_model()
model.summary()

# ==========================
# COMPILE MODEL
# ==========================

model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

# ==========================
# TRAIN MODEL
# ==========================

history = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=EPOCHS,
    callbacks=[
        EarlyStopping(patience=5, restore_best_weights=True),
        ReduceLROnPlateau(patience=2)
    ]
)

# ==========================
# EVALUATION
# ==========================

pred = []
true = []

for x, y in test_dataset:
    p = model.predict(x, verbose=0)
    pred.extend(np.argmax(p, axis=1))
    true.extend(y.numpy())

pred = np.array(pred)
true = np.array(true)

accuracy = np.mean(pred == true)
precision = precision_score(true, pred, average="weighted")
recall = recall_score(true, pred, average="weighted")
f1 = f1_score(true, pred, average="weighted")

print("\nACCURACY:", accuracy)
print("PRECISION:", precision)
print("RECALL:", recall)
print("F1 SCORE:", f1)

# ==========================
# CLASSIFICATION REPORT
# ==========================

print(classification_report(true, pred, target_names=class_names))

# ==========================
# CONFUSION MATRIX
# ==========================

cm = confusion_matrix(true, pred)

plt.figure(figsize=(8,8))
sns.heatmap(cm, annot=True, fmt="d",
            xticklabels=class_names,
            yticklabels=class_names)
plt.title("Confusion Matrix")
plt.show()

# ==========================
# ACCURACY GRAPH
# ==========================

plt.plot(history.history["accuracy"])
plt.plot(history.history["val_accuracy"])
plt.title("Model Accuracy")
plt.legend(["Train", "Validation"])
plt.show()

# ==========================
# LOSS GRAPH
# ==========================

plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.title("Model Loss")
plt.legend(["Train", "Validation"])
plt.show()

# ==========================
# SAVE MODEL
# ==========================

model.save("car_classification_model.h5")

print("PROJECT COMPLETED 🚗🔥")
# Out:
# 2026-06-11 12:50:42.587206: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1781182243.003078      58 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1781182243.122233      58 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1781182244.158283      58 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1781182244.158327      58 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1781182244.158330      58 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1781182244.158333      58 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# TensorFlow Version: 2.19.0
# /kaggle/input/datasets/kshitij192/cars-image-dataset/Cars Dataset
# /kaggle/input/datasets/kshitij192/cars-image-dataset/Cars Dataset/test
# /kaggle/input/datasets/kshitij192/cars-image-dataset/Cars Dataset/test/Hyundai Creta
# /kaggle/input/datasets/kshitij192/cars-image-dataset/Cars Dataset/test/Tata Safari
# /kaggle/input/datasets/kshitij192/cars-image-dataset/Cars Dataset/test/Swift
# /kaggle/input/datasets/kshitij192/cars-image-dataset/Cars Dataset/test/Mahindra Scorpio
# /kaggle/input/datasets/kshitij192/cars-image-dataset/Cars Dataset/test/Toyota Innova
# /kaggle/input/datasets/kshitij192/cars-image-dataset/Cars Dataset/test/Rolls Royce
# /kaggle/input/datasets/kshitij192/cars-image-dataset/Cars Dataset/test/Audi
# /kaggle/input/datasets/kshitij192/cars-image-dataset/Cars Dataset/train
# /kaggle/input/datasets/kshitij192/cars-image-dataset/Cars Dataset/train/Hyundai Creta
# /kaggle/input/datasets/kshitij192/cars-image-dataset/Cars Dataset/train/Tata Safari
# /kaggle/input/datasets/kshitij192/cars-image-dataset/Cars Dataset/train/Swift
# /kaggle/input/datasets/kshitij192/cars-image-dataset/Cars Dataset/train/Mahindra Scorpio
# /kaggle/input/datasets/kshitij192/cars-image-dataset/Cars Dataset/train/Toyota Innova
# /kaggle/input/datasets/kshitij192/cars-image-dataset/Cars Dataset/train/Rolls Royce
# /kaggle/input/datasets/kshitij192/cars-image-dataset/Cars Dataset/train/Audi
# Train Exists: True
# Test Exists: True
# Found 3352 files belonging to 7 classes.
# Using 2682 files for training.
# I0000 00:00:1781182271.998083      58 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13757 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1781182272.004475      58 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13757 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Found 3352 files belonging to 7 classes.
# Using 670 files for validation.
# Found 813 files belonging to 7 classes.
# Classes: ['Audi', 'Hyundai Creta', 'Mahindra Scorpio', 'Rolls Royce', 'Swift', 'Tata Safari', 'Toyota Innova']
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential          │ (None, 128, 128,  │          0 │ input_layer[0][0] │
# │ (Sequential)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rescaling           │ (None, 128, 128,  │          0 │ sequential[0][0]  │
# │ (Rescaling)         │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 128, 128,  │        896 │ rescaling[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 64, 64,    │          0 │ conv2d[0][0]      │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 64, 64,    │      1,056 │ max_pooling2d[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 64, 64,    │      9,248 │ max_pooling2d[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 64, 64,    │     25,632 │ max_pooling2d[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 64, 64,    │          0 │ conv2d_1[0][0],   │
# │ (Concatenate)       │ 96)               │            │ conv2d_2[0][0],   │
# │                     │                   │            │ conv2d_3[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 64, 64,    │     55,360 │ concatenate[0][0] │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 64, 64,    │        256 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu (ReLU)        │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 64, 64,    │     36,928 │ re_lu[0][0]       │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 64, 64,    │      6,208 │ concatenate[0][0] │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │ conv2d_4[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_1 (ReLU)      │ (None, 64, 64,    │          0 │ add[0][0]         │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 32, 32,    │          0 │ re_lu_1[0][0]     │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 64)        │          0 │ max_pooling2d_1[… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 8)         │        520 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 64)        │        576 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape (Reshape)   │ (None, 1, 1, 64)  │          0 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply (Multiply) │ (None, 32, 32,    │          0 │ max_pooling2d_1[… │
# │                     │ 64)               │            │ reshape[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 32, 32,    │     73,856 │ multiply[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_2 (ReLU)      │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 32, 32,    │    147,584 │ re_lu_2[0][0]     │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 32, 32,    │      8,320 │ multiply[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │ conv2d_7[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_3 (ReLU)      │ (None, 32, 32,    │          0 │ add_1[0][0]       │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 16, 16,    │          0 │ re_lu_3[0][0]     │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ max_pooling2d_2[… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 128)       │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 256)       │     33,024 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 7)         │      1,799 │ dense_2[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 402,543 (1.54 MB)
#  Trainable params: 401,775 (1.53 MB)
#  Non-trainable params: 768 (3.00 KB)
# Epoch 1/20
# I0000 00:00:1781182285.415912     140 cuda_dnn.cc:529] Loaded cuDNN version 91002
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 21s 105ms/step - accuracy: 0.2826 - loss: 1.8301 - val_accuracy: 0.2582 - val_loss: 1.8537 - learning_rate: 0.0010
# Epoch 2/20
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 6s 73ms/step - accuracy: 0.3434 - loss: 1.7390 - val_accuracy: 0.3104 - val_loss: 1.7833 - learning_rate: 0.0010
# Epoch 3/20
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 6s 73ms/step - accuracy: 0.3591 - loss: 1.6951 - val_accuracy: 0.2836 - val_loss: 1.8281 - learning_rate: 0.0010
# Epoch 4/20
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 6s 74ms/step - accuracy: 0.3758 - loss: 1.6593 - val_accuracy: 0.3179 - val_loss: 1.8480 - learning_rate: 0.0010
# Epoch 5/20
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 6s 74ms/step - accuracy: 0.4019 - loss: 1.6007 - val_accuracy: 0.4299 - val_loss: 1.5451 - learning_rate: 1.0000e-04
# Epoch 6/20
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 6s 74ms/step - accuracy: 0.4101 - loss: 1.5784 - val_accuracy: 0.4149 - val_loss: 1.5802 - learning_rate: 1.0000e-04
# Epoch 7/20
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 6s 75ms/step - accuracy: 0.4206 - loss: 1.5652 - val_accuracy: 0.4164 - val_loss: 1.5756 - learning_rate: 1.0000e-04
# Epoch 8/20
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 6s 75ms/step - accuracy: 0.4325 - loss: 1.5423 - val_accuracy: 0.4373 - val_loss: 1.5546 - learning_rate: 1.0000e-05
# Epoch 9/20
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 6s 76ms/step - accuracy: 0.4265 - loss: 1.5534 - val_accuracy: 0.4299 - val_loss: 1.5463 - learning_rate: 1.0000e-05
# Epoch 10/20
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 6s 77ms/step - accuracy: 0.4288 - loss: 1.5439 - val_accuracy: 0.4284 - val_loss: 1.5468 - learning_rate: 1.0000e-06
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ACCURACY: 0.4218942189421894
# PRECISION: 0.40753347653564265
# RECALL: 0.4218942189421894
# F1 SCORE: 0.350527110821965
#                   precision    recall  f1-score   support
#
#             Audi       0.41      0.82      0.55       199
#    Hyundai Creta       0.33      0.03      0.05        67
# Mahindra Scorpio       0.39      0.15      0.21        75
#      Rolls Royce       0.00      0.00      0.00        74
#            Swift       0.75      0.26      0.39       102
#      Tata Safari       0.42      0.13      0.20       106
#    Toyota Innova       0.40      0.66      0.50       190
#
#         accuracy                           0.42       813
#        macro avg       0.39      0.29      0.27       813
#     weighted avg       0.41      0.42      0.35       813
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# PROJECT COMPLETED 🚗🔥
